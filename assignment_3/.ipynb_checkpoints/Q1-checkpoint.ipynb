# %%
import numpy as np 
import matplotlib.pyplot as plt

# if .py file is edited, reload as follows:
#import importlib
#import Q1_Function
#importlib.reload(Q1_Function)

from Q1_Function import diverged #importing fcn

# %%
x = np.linspace(-2, 2, 500)
y = np.linspace(-2, 2, 500)

# %%
diverge, it_of_diverge = diverged(x, y, res = 500, max_iter = 100)

# %%
plt.figure(figsize=(7,7))
plt.imshow(diverge, extent=(-2,2,-2,2), cmap='gray')

plt.title("Diverging vs Bounded points")
plt.xlabel("Re(c)")
plt.ylabel("Im(c)")

plt.text(
    0.5, -1.5,
    "Black: Converges\nWhite: Diverges",
    bbox=dict(facecolor='white', alpha=0.8)
)

plt.show()

# %%
# figure showing colour map corresponding to the iteration of which a value diverges
plt.figure(figsize=(7,7))

img = plt.imshow(it_of_diverge, extent=(-2, 2, -2, 2), cmap='viridis', origin='lower')

plt.title("Iteration of Divergence")
plt.xlabel("Re(c)")
plt.ylabel("Im(c)")

plt.colorbar(img, label="Iteration of divergence")

plt.show()
